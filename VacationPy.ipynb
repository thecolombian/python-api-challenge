# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv
from holoviews import dim, opts
from bokeh.io.export import get_screenshot_as_png
hv.extension('bokeh')
from bokeh.palettes import Category20

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1285'>
#   <div id="a02618e2-d201-4eb4-ad2c-d8bc66b6279d" data-root-id="p1285" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          polyarnyy  69.1989   33.4478     15.70        64
# 1        1       al majaridah  19.1236   41.9111     37.11        19
# 2        2         bredasdorp -34.5322   20.0403     10.68        79
# 3        3           bilibino  68.0546  166.4372      7.91        88
# 4        4  port-aux-francais -49.3500   70.2167      0.82        74
#
#    Cloudiness  Wind Speed Country        Date
# 0          16       11.69      RU  1720336334
# 1         100        2.80      SA  1720336334
# 2          23        5.47      ZA  1720336334
# 3         100        1.93      RU  1720336334
# 4          73       12.27      TF  1720336335

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Basic Map no frills 

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600, 
    scale = 0.5,
    color = "City"
)

# Save the map plot to a file
# hv.save(map_plot, 'output_data/city_humidity_map.png', fmt='png')
# map_plot.savefig("output_data/city_humidity_map.png", bbox_inches='tight')

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
# Enahnced Map with zoom capabilities

# Configure the map plot
# YOUR CODE HERE

# Convert Humidity to a size scale (optional, for better visualization)
city_data_df['Humidity_Scaled'] = city_data_df['Humidity'] * 0.5

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="EsriImagery",
    size="Humidity_Scaled",  # Use scaled humidity for point sizes
    frame_width=800,
    frame_height=600,
    scale=0.5,
    color="Humidity",  # Use a continuous color map for Humidity
    hover_cols=["City", "Humidity", "Max Temp", "Wind Speed"],
    title="City Locations with Humidity Levels",
    cmap='viridis'  # Apply colormap
).opts(
    tools=['hover'],  # Add hover tool for interactivity
    bgcolor='white',  # Set background color
    toolbar='above',  # Position toolbar above the plot
    active_tools=['wheel_zoom']  # Set active tools for better interactivity
)

# Save the map plot to a file
#hv.save(map_plot, 'output_data/city_humidity_map.html', fmt='html')

# Display the map plot
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Humidity_Scaled,City,Max Temp,Wind Speed)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Define conditions
min_temp_s = city_data_df["Max Temp"] > 21
max_temp_s = city_data_df["Max Temp"] < 27
wind_speed_s = city_data_df["Wind Speed"] < 4.5 
zero_cloudiness_s = city_data_df["Cloudiness"] == 0

# Combine conditions
combined_conditions = min_temp_s & max_temp_s & wind_speed_s & zero_cloudiness_s

# Drop any rows with null values
# YOUR CODE HERE
# Filter the DataFrame based on combined conditions
clean_city_temp_range_df = city_data_df[combined_conditions].dropna()

# Display sample data
# YOUR CODE HERE
clean_city_temp_range_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 7          7              koryazhma  61.3143   47.1691     21.74        45
# 13        13                 shiloh  38.5614  -89.8973     22.50        87
# 46        46             los chavez  34.7270 -106.7384     25.97        12
# 83        83  ariano irpino-martiri  41.1489   15.0833     22.75        39
# 142      142            farafangana -22.8167   47.8333     21.57        55
# 268      268               portland  45.5234 -122.6762     24.77        57
# 276      276          carl junction  37.1767  -94.5655     22.38        71
# 351      351               karratha -20.7377  116.8463     22.19        36
# 366      366                  sirte  31.2089   16.5887     26.61        59
# 428      428              tucumcari  35.1717 -103.7250     21.91        56
# 487      487               usogorsk  63.4106   48.6872     21.24        42
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_city_temp_range_df.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 7          7              koryazhma  61.3143   47.1691     21.74        45
# 13        13                 shiloh  38.5614  -89.8973     22.50        87
# 46        46             los chavez  34.7270 -106.7384     25.97        12
# 83        83  ariano irpino-martiri  41.1489   15.0833     22.75        39
# 142      142            farafangana -22.8167   47.8333     21.57        55
# 268      268               portland  45.5234 -122.6762     24.77        57
# 276      276          carl junction  37.1767  -94.5655     22.38        71
# 351      351               karratha -20.7377  116.8463     22.19        36
# 366      366                  sirte  31.2089   16.5887     26.61        59
# 428      428              tucumcari  35.1717 -103.7250     21.91        56
# 487      487               usogorsk  63.4106   48.6872     21.24        42
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 1
categories = "accommodation.hotel"

params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key     
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
   

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# koryazhma - nearest hotel: Виконда
# shiloh - nearest hotel: Holiday Inn Express
# los chavez - nearest hotel: Mesa Inn Hotel
# ariano irpino-martiri - nearest hotel: No hotel found
# farafangana - nearest hotel: Le Concombre Masqué
# portland - nearest hotel: the Hoxton
# carl junction - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# sirte - nearest hotel: فندق المدينة-سرت
# tucumcari - nearest hotel: Pow Wow Inn
# usogorsk - nearest hotel: Единственная
# nsanje - nearest hotel: No hotel found
# newton - nearest hotel: Four Points by Sheraton
# leskovac - nearest hotel: Apartmani Asterix
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 7          7              koryazhma  61.3143   47.1691     21.74        45
# 13        13                 shiloh  38.5614  -89.8973     22.50        87
# 46        46             los chavez  34.7270 -106.7384     25.97        12
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Basic Graph :) 

# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600, 
    scale = 0.5,
    color = "City"
)

# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)

# %%
# Enhanced MAP with Zoom capabilities

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# Ensure the Bokeh extension is loaded
hv.extension('bokeh')

# Define a scaling factor for the point sizes
hotel_df['Size'] = 580  # Fixed size for all points 

# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="EsriImagery",
    size="Size",  # Size of the points
    frame_width=800,
    frame_height=600,
    scale=0.5,
    color="City",  # Use a color based on the 'City' column
    hover_cols=["City", "Hotel Name", "Humidity", "Max Temp", "Wind Speed"],  # Include hover information
    title="Hotel Locations with Humidity Levels"
).opts(
    tools=['hover'],  # Add hover tool for interactivity
    bgcolor='white',  # Set background color
    toolbar='above',  # Position toolbar above the plot
    active_tools=['wheel_zoom']  # Set active tools just for fun :) 
)

# Display the map plot
hotel_map_plot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1584'>
#   <div id="e2ff3d1c-3ff7-4f6e-b5c3-c1901ef6449b" data-root-id="p1584" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
